# %%
import boto3

# Initialize the AWS IoT Analytics client
client = boto3.client('iotanalytics', region_name='ap-south-1')

# Specify the ARN of the dataset
dataset_arn = 'arn:aws:iotanalytics:ap-south-1:019220772077:dataset/analytics_dataset'

# Specify the name of your data store within the dataset
data_store_name = 'analytics_datastore'

# Specify the time range for data retrieval
start_time = '2023-01-01T00:00:00Z'
end_time = '2023-02-01T00:00:00Z'

# Retrieve data from the dataset
response = client.get_dataset_content(
    datasetName=dataset_arn,
    versionId='LATEST',  # or specify a version
    startTime=start_time,
    endTime=end_time,
    datastoreName=data_store_name
)

# Extract and process the data from the response
data_entries = response.get('entries', [])

# Process the data as needed
for entry in data_entries:
    # Your data processing logic here
    print(entry)
# Out:
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# c:\Users\Abhishek Patil\Desktop\IOE AWS\Lab project\notebook.ipynb Cell 1 line <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/Abhishek%20Patil/Desktop/IOE%20AWS/Lab%20project/notebook.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a> end_time = '2023-02-01T00:00:00Z'
#      <a href='vscode-notebook-cell:/c%3A/Users/Abhishek%20Patil/Desktop/IOE%20AWS/Lab%20project/notebook.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a> # Retrieve data from the dataset
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Abhishek%20Patil/Desktop/IOE%20AWS/Lab%20project/notebook.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a> response = client.get_dataset_content(
#      <a href='vscode-notebook-cell:/c%3A/Users/Abhishek%20Patil/Desktop/IOE%20AWS/Lab%20project/notebook.ipynb#W0sZmlsZQ%3D%3D?line=17'>18</a>     datasetName=dataset_arn,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have columns named 'temperature', 'humidity', and 'moisture' in your DataFrame 'df'
temp_values = df['temperature']
humidity_values = df['humidity']
moisture_values = df['moisture']

# Create a sequential range of integers as x-axis values
x_values = np.arange(len(temp_values))

# Set a consistent figure size for all charts
plt.figure(figsize=(10, 6))  # Set the figure size (consistent width, larger height)

# Temperature Line Chart
plt.subplot(3, 1, 1)  # Create the first subplot
plt.plot(x_values, temp_values, marker='o', linestyle='-', color='blue')
plt.xlabel('Data Point')
plt.ylabel('Temperature (°C)')
plt.title('Line Chart of Temperature')

# Humidity Line Chart
plt.subplot(3, 1, 2)  # Create the second subplot
plt.plot(x_values, humidity_values, marker='o', linestyle='-', color='green')
plt.xlabel('Data Point')
plt.ylabel('Humidity (%)')
plt.title('Line Chart of Humidity')

# Moisture Line Chart
plt.subplot(3, 1, 3)  # Create the third subplot
plt.plot(x_values, moisture_values, marker='o', linestyle='-', color='red')
plt.xlabel('Data Point')
plt.ylabel('Moisture (%)')
plt.title('Line Chart of Moisture')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Count the occurrences of each unique value in the 'lightstate' column
lightstate_counts = df['lightstate'].value_counts()

# Create a pie chart using Seaborn
plt.figure(figsize=(6, 6))  # Set the figure size (optional)
sns.set_style("whitegrid")  # Set style (optional)
sns.set_palette("Set3")  # Set color palette (optional)
plt.pie(lightstate_counts, labels=lightstate_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Pie Chart of Light State')
plt.show()
